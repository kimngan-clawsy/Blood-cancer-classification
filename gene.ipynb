# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Class/HK6/IPrj/Datasets/merged_AML_ALL.csv')
df
# Out:
#       Unnamed: 0  target  1007_s_at   1053_at    117_at    121_at  1255_g_at  \
# 0              0       2   7.409521  5.009216  4.173607  7.315369   3.185411
# 1              1       2   7.177109  5.415108  4.426778  7.550818   3.134181
# 2              2       2   6.564918  5.248020  4.252414  7.175169   3.017718
# 3              3       2   6.872028  5.155963  4.388849  7.365933   3.031735
# 4              4       2   7.402105  5.509826  4.284291  7.214947   2.925269
# ...          ...     ...        ...       ...       ...       ...        ...
# 3650        3650       0   0.113765  0.859063  0.066194  1.055261  -1.640361
# 3651        3651       0  -0.001656  0.736877 -0.042692  0.883866  -1.622765
# 3652        3652       0  -0.136640  0.994290  0.176942  0.689586  -1.361585
# 3653        3653       0   0.084627  0.766523  0.160465  1.008582  -1.323178
# 3654        3654       0   0.143818  0.742823 -0.139263  0.891654  -1.501160
#
# ...

# %%
selected_gene = ['201904_s_at',
 '207890_s_at',
 '215332_s_at',
 '206515_at',
 '215608_at',
 '215130_s_at',
 '212531_at',
 '211772_x_at',
 '201523_x_at',
 '205821_at',
 '206067_s_at',
 '203032_s_at',
 '208760_at',
 '211350_s_at',
 '200965_s_at',
 '221928_at',
 '213110_s_at',
 '214823_at',
 '209758_s_at',
 '204561_x_at',
 '209772_s_at',
 '207576_x_at',
 '221281_at',
 '206674_at',
 '208022_s_at',
 '209359_x_at',
 '214735_at',
 '207796_x_at',
 '200751_s_at',
 '212914_at',
 '207636_at',
 '38158_at',
 '209365_s_at']

df[selected_gene]
# Out:
#       201904_s_at  207890_s_at  215332_s_at  206515_at  215608_at  \
# 0        5.116778     4.647639     3.390108   3.340158   4.347914
# 1        5.376389     4.981526     3.138225   3.369771   4.455415
# 2        5.200842     4.242276     3.089459   3.200331   4.341362
# 3        5.342169     4.439446     3.051094   3.299129   4.039487
# 4        5.453730     4.522231     3.168410   3.114832   4.025664
# ...           ...          ...          ...        ...        ...
# 3650     1.030723     1.423168    -0.659964   1.731368   0.099030
# 3651     1.051771     1.394420    -0.587088   1.779488   0.056241
# 3652     1.222505     1.544846    -0.698581   1.890472   0.080798
# 3653     1.287979     1.702420    -0.768103   1.678061   0.111899
# 3654     1.089374     1.477762     0.239309   1.780598   0.027553
#
#       215130_s_at  212531_at  211772_x_at  201523_x_at  205821_at  ...  \
# 0        4.276546   3.928193     2.879254     7.197564   6.057804  ...
# ...

# %%
filter_gene = ["234632_x_at","209603_at","230527_at","229963_at","217901_at","214719_at","219513_s_at","210789_x_at","204777_s_at","203294_s_at","230753_at","242056_at","217680_x_at","214945_at","222312_s_at","214705_at","241688_at","241611_s_at","236952_at","207636_at","243659_at","226311_at","211772_x_at","244719_at","239766_at","243272_at"]
df[filter_gene]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 filter_gene = ["234632_x_at","209603_at","230527_at","229963_at","217901_at","214719_at","219513_s_at","210789_x_at","204777_s_at","203294_s_at","230753_at","242056_at","217680_x_at","214945_at","222312_s_at","214705_at","241688_at","241611_s_at","236952_at","207636_at","243659_at","226311_at","211772_x_at","244719_at","239766_at","243272_at"]
# ----> 2 df[filter_gene]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
# ...
